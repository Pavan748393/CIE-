# %% [markdown]
# <a href="https://colab.research.google.com/github/Pavan748393/CIE-/blob/main/iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/apple_jobs.csv')
df
# Out:
#                                       title  \
# 0                       Software Technician
# 1                         Software Engineer
# 2                         Software Engineer
# 3                         Software Engineer
# 4                         Software Engineer
# ...                                     ...
# 2143   Enterprise Carrier Account Executive
# 2144             Major Account Lead, Russia
# 2145  Business Solutions Manager, Education
# 2146                Enterprise Channel Lead
# 2147                    Consulting Engineer
#
#                                                location  \
# 0     Santa Clara Valley (Cupertino), California, Un...
# 1     Santa Clara Valley (Cupertino), California, Un...
# 2     Santa Clara Valley (Cupertino), California, Un...
# 3     Santa Clara Valley (Cupertino), California, Un...
# 4     Santa Clara Valley (Cupertino), California, Un...
# ...                                                 ...
# ...

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Length: 150, dtype: bool

# %%
import seaborn as sns
df=sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(x=df.index,y=df['petal_width'],hue=df['species'])
# Out:
# <Axes: xlabel='None', ylabel='petal_width'>

# %%
sns.barplot(y=df['petal_length'],hue=df['species'])
# Out:
# <Axes: ylabel='petal_length'>

# %%
sns.histplot(x=df['petal_width'],hue=df['species'])
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
sns.lineplot(x=df.index, y=df['sepal_width'],hue=df['species'])
# Out:
# <Axes: xlabel='None', ylabel='sepal_width'>

# %%
sns.kdeplot(x=df.index, y=df['sepal_width'],hue=df['species'])
# Out:
# <Axes: xlabel='None', ylabel='sepal_width'>

# %%
sns.boxplot(x=df['sepal_length'],hue=df['species'])
# Out:
# <Axes: xlabel='sepal_length'>

# %%
sns.displot(x=df['sepal_length'],hue=df['species'])

# %%
df = pd.read_csv('/content/iris.csv')

sns.violinplot(x=df['sepal_length'], hue=df['species'])
# Out:
# <Axes: xlabel='sepal_length'>

# %%
import numpy as np
from scipy import stats
data = np.array([10, 15, 20, 25, 30, 35, 40, 45, 50, 55])
mean = np.mean(data)
median = np.median(data)
mode = stats.mode(data).mode
print(f"Mean: {mean}")
print(f"Median: {median}")
print(f"Mode: {mode}")
# Out:
# Mean: 32.5
# Median: 32.5
# Mode: 10

# %%
import numpy as np
from scipy import stats
data = np.array([10, 15, 20, 25, 30, 35, 40, 45, 50, 55])
mean = np.mean(data)
median = np.median(data)
mode = stats.mode(data).mode
data_range = np.ptp(data)
variance = np.var(data)
std_deviation = np.std(data)
iqr = np.percentile(data, 75) - np.percentile(data, 25)

print("Central Tendency:")
print(f"Mean: {mean}")
print(f"Median: {median}")
print(f"Mode: {mode}")

print("\nDispersion:")
print(f"Range: {data_range}")
print(f"Variance: {variance}")
print(f"Standard Deviation: {std_deviation}")
print(f"IQR: {iqr}")
# Out:
# Central Tendency:
# Mean: 32.5
# Median: 32.5
# Mode: 10
#
# Dispersion:
# Range: 45
# Variance: 206.25
# Standard Deviation: 14.361406616345072
# IQR: 22.5

# %%
import numpy as np
data = np.array([10, 15, 20, 25, 30, 35, 40, 45, 50, 55])
data_range = np.ptp(data)
variance = np.var(data)
std_deviation = np.std(data)
iqr = np.percentile(data, 75) - np.percentile(data, 25)
print(f"Range: {data_range}")
print(f"Variance: {variance}")
print(f"Standard Deviation: {std_deviation}")
print(f"IQR: {iqr}")
# Out:
# Range: 45
# Variance: 206.25
# Standard Deviation: 14.361406616345072
# IQR: 22.5

# %%
import pandas as pd
data = pd.Series([10, 15, 20, 25, 30, 35, 40, 45, 50, 55])
skewness = data.skew()
kurtosis = data.kurtosis()
print(f"Skewness: {skewness}")
print(f"Kurtosis: {kurtosis}")
# Out:
# Skewness: 0.0
# Kurtosis: -1.2000000000000002

# %%
import pandas as pd
data = pd.Series([10, 15, 20, 25, 30, 35, 40, 45, 50, 55])

frequency_counts = data.value_counts()
print("Frequency Counts:")
print(frequency_counts)
# Out:
# Frequency Counts:
# 10    1
# 15    1
# 20    1
# 25    1
# 30    1
# 35    1
# 40    1
# 45    1
# 50    1
# 55    1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
data = [10, 15, 20, 25, 30, 35, 40, 45, 50, 55]
plt.hist(data, bins=10, edgecolor='k', alpha=0.7)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Data')
plt.show()

# %%
import seaborn as sns
data = [10, 15, 20, 25, 30, 35, 40, 45, 50, 55]
sns.kdeplot(data, shade=True)
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Kernel Density Estimation (KDE) Plot')
plt.show()
# Out:
# <ipython-input-19-5b992800e641>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data, shade=True)

# %%
import seaborn as sns
data = [10, 15, 20, 25, 30, 35, 40, 45, 50, 55]
sns.boxplot(data=data)
plt.xlabel('Data')
plt.title('Box Plot of Data')
plt.show()

# %%
group1 = [10, 15, 20, 25, 30, 35, 40, 45, 50, 55]
group2 = [5, 15, 25, 35, 45, 55, 65, 75, 85, 95]
sns.boxplot(data=[group1, group2], notch=True)
plt.xticks([0, 1], ['Group 1', 'Group 2'])
plt.xlabel('Groups')
plt.ylabel('Data')
plt.title('Box Plot Comparison of Two Groups')
plt.show()

# %%
import matplotlib.pyplot as plt
labels = ['Category A', 'Category B', 'Category C']
sizes = [30, 45, 25]
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.
plt.title('Pie Chart of Composition')
plt.show()

# %%
import matplotlib.pyplot as plt
categories = ['Category A', 'Category B', 'Category C']
values = [30, 45, 25]
plt.bar(categories, values)
plt.xlabel('Categories')
plt.ylabel('Counts')
plt.title('Bar Chart of Composition')
plt.show()

# %%
sns.scatterplot(x=df.index,y=df['petal_width'],hue=df['species'])
# Out:
# <Axes: xlabel='None', ylabel='petal_width'>

# %%
if 'df' in locals():
    print("DataFrame 'df' exists.")
    print("Columns in df:", df.columns)
# Out:
# DataFrame 'df' exists.
# Columns in df: Index(['sepal_length', 'other_column'], dtype='object')

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('/content/tips.csv')
plt.figure(figsize=(6,6))
plt.title('line plot of total bill')
plt.xlabel('index',fontsize=20)
plt.ylabel('total bill',fontsize=20)
plt.plot(df.index,df['total_bill'],markevery=1,marker='d')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.set(rc={'figure.figsize':(5,5)})
sns.swarmplot(x='day',y='total_bill',data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
df = pd.read_csv('/content/iris.csv')
sns.distplot(df['petal_width'], kde=False, color='black', bins=10)
plt.show()
# Out:
# <ipython-input-59-badfaf8715d5>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['petal_width'], kde=False, color='black', bins=10)

# %%
plt.figure(figsize=(5,5))
df['petal_length'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
sns.set(rc={'figure.figsize':(5,5)})
sns.kdeplot(df['petal_width'],shade=True)
# Out:
# <ipython-input-61-6334d58a0dbd>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['petal_width'],shade=True)
# <Axes: xlabel='petal_width', ylabel='Density'>

# %%
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt
kdf=df['sepal_length'].to_numpy()
rdf=np.hstack(kdf)
density=stats.kde.gaussian_kde(rdf)
x=np.linspace(3,9,100)
plt.plot(x,density(x))
plt.plot(rdf,[0.01]*len(rdf),'|')
# Out:
# <ipython-input-17-9e97fa25cca7>:7: DeprecationWarning: Please import `gaussian_kde` from the `scipy.stats` namespace; the `scipy.stats.kde` namespace is deprecated and will be removed in SciPy 2.0.0.
#   density=stats.kde.gaussian_kde(rdf)

# %%
import seaborn as sns
import pandas as pd
data = {'sepal_length': [5.1, 4.9, 4.7, 4.6, 5.0],
        'other_column': [1, 2, 3, 4, 5]}
df = pd.DataFrame(data)
sns.boxplot(x=df['sepal_length'])
# Out:
# <Axes: xlabel='sepal_length'>

# %%
import seaborn as sns
import pandas as pd
sns.set(rc={'figure.figsize':(5,5)})
sns.boxplot(x='variable',y='value',data=pd.melt(df))
# Out:
# <Axes: xlabel='variable', ylabel='value'>

# %%
sns.set(rc={'figure.figsize':(6,6)})
sns.displot(df['sepal_length'],color='black',rug=True)

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('/content/titanic (2).csv')
print(df.columns)
print(df['PassengerId'].dtype)
print(df['PassengerId'].isnull().sum())
plt.figure(figsize=(5, 5))
df['PassengerId'].plot(kind='density')
plt.show()
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
# int64
# 0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots()
sns.rugplot(df['sepal_length'], ax=ax)
ax.set_xlim(3, 9)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('/content/titanic (2).csv')
kdf=df['Survived'].to_numpy()
rdf=np.hstack(kdf)
density=stats.kde.gaussian_kde.gaussian_kde(edf)
x=np.linspace(3,9,100)
plt.plot(x,density(x))
plt.plot(rdf,[0.01]*len(rdf),'|')
# Out:
# <ipython-input-18-0ed5a0bbf73b>:6: DeprecationWarning: Please import `gaussian_kde` from the `scipy.stats` namespace; the `scipy.stats.kde` namespace is deprecated and will be removed in SciPy 2.0.0.
#   density=stats.kde.gaussian_kde.gaussian_kde(edf)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-0ed5a0bbf73b> in <cell line: 6>()
#       4 kdf=df['Survived'].to_numpy()
#       5 rdf=np.hstack(kdf)
# ----> 6 density=stats.kde.gaussian_kde.gaussian_kde(edf)
#       7 x=np.linspace(3,9,100)
#       8 plt.plot(x,density(x))
#
# AttributeError: type object 'gaussian_kde' has no attribute 'gaussian_kde'

# %%
df = pd.read_csv('/content/titanic (2).csv')
kdf = df['Survived'].to_numpy()
rdf = np.hstack(kdf)
density = gaussian_kde(rdf)
x = np.linspace(0, 2, 100)
plt.plot(x, density(x))
plt.plot(rdf, [0.01] * len(rdf), '|')
plt.show()
